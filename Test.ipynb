# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.applications.vgg16 import decode_predictions
import matplotlib.pyplot as plt
import cv2

# Muat model dari file h5
model = tf.keras.models.load_model('ModelBagusFix.h5')

# Fungsi untuk memuat dan memproses gambar untuk model
def load_and_preprocess_image(img_path):
    img = image.load_img(img_path, target_size=(224, 224))  # Ubah ukuran sesuai dengan model Anda
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)
    return img_array
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
img_path = 'acne.jpeg'  # Ganti dengan path gambar Anda
test_image = load_and_preprocess_image(img_path)

# Predict using the model
predictions = model.predict(test_image)

# Define class labels (Replace with your actual class labels)
class_labels = [
    'Warts Molluscum and other Viral Infections', 'Vasculitis Photos', 'Vascular Tumors', 'Urticaria Hives',
    'Tinea Ringworm Candidiasis and other Fungal Infections', 'Systemic Disease', 'Seborrheic Keratoses and other Benign Tumors',
    'Scabies Lyme Disease and other Infestations and Bites', 'Psoriasis pictures Lichen Planus and related diseases',
    'Poison Ivy Photos and other Contact Dermatitis', 'Nail Fungus and other Nail Disease', 'Melanoma Skin Cancer Nevi and Moles',
    'Lupus and other Connective Tissue diseases', 'Light Diseases and Disorders of Pigmentation', 'Herpes HPV and other STDs Photos',
    'Hair Loss Photos Alopecia and other Hair Diseases', 'Exanthems and Drug Eruptions', 'Eczema Photos',
    'Cellulitis Impetigo and other Bacterial Infections', 'Bullous Disease Photos', 'Atopic Dermatitis Photos',
    'Actinic Keratosis Basal Cell Carcinoma and other Malignant Lesions', 'Acne and Rosacea Photos'
]

# Get the label and confidence for each prediction
for idx, pred in enumerate(predictions[0]):
    print(f'{class_labels[idx]}: {pred:.2%}')

# Visualize the image with prediction label and confidence score
plt.imshow(image.load_img(img_path))
predicted_label = class_labels[np.argmax(predictions)]
confidence = np.max(predictions)
plt.title(f'Predicted: {predicted_label} ({confidence:.2%})')
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Warts Molluscum and other Viral Infections: 13.33%
# Vasculitis Photos: 0.00%
# Vascular Tumors: 0.00%
# Urticaria Hives: 0.00%
# Tinea Ringworm Candidiasis and other Fungal Infections: 36.64%
# Systemic Disease: 0.00%
# Seborrheic Keratoses and other Benign Tumors: 0.00%
# Scabies Lyme Disease and other Infestations and Bites: 1.95%
# Psoriasis pictures Lichen Planus and related diseases: 0.00%
# Poison Ivy Photos and other Contact Dermatitis: 0.07%
# Nail Fungus and other Nail Disease: 43.53%
# Melanoma Skin Cancer Nevi and Moles: 0.00%
# Lupus and other Connective Tissue diseases: 3.70%
# Light Diseases and Disorders of Pigmentation: 0.00%
# Herpes HPV and other STDs Photos: 0.07%
# Hair Loss Photos Alopecia and other Hair Diseases: 0.00%
# Exanthems and Drug Eruptions: 0.17%
# Eczema Photos: 0.01%
# Cellulitis Impetigo and other Bacterial Infections: 0.25%
# Bullous Disease Photos: 0.00%
# Atopic Dermatitis Photos: 0.21%
# Actinic Keratosis Basal Cell Carcinoma and other Malignant Lesions: 0.02%
# Acne and Rosacea Photos: 0.05%
